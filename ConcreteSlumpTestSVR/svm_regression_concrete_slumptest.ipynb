# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-Title:-Using-Support-Vector-Machine-(SVM)-Regression,-Predict-Concrete-Compressive-Strength-based-on-Concrete-Slump-Tests" data-toc-modified-id="Project-Title:-Using-Support-Vector-Machine-(SVM)-Regression,-Predict-Concrete-Compressive-Strength-based-on-Concrete-Slump-Tests-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Project Title: Using Support Vector Machine (SVM) Regression, Predict Concrete Compressive Strength based on Concrete Slump Tests</a></span><ul class="toc-item"><li><span><a href="#Project-Background" data-toc-modified-id="Project-Background-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project Background</a></span></li><li><span><a href="#Project-Methodology" data-toc-modified-id="Project-Methodology-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Project Methodology</a></span></li><li><span><a href="#Problem-Identification" data-toc-modified-id="Problem-Identification-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Problem Identification</a></span></li></ul></li><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Wrangling</a></span><ul class="toc-item"><li><span><a href="#Identification-and-Collection-of-Datasets" data-toc-modified-id="Identification-and-Collection-of-Datasets-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Identification and Collection of Datasets</a></span></li><li><span><a href="#Loading-of-Core-Packages" data-toc-modified-id="Loading-of-Core-Packages-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Loading of Core Packages</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis (EDA)</a></span></li><li><span><a href="#Pre-Processing-and-Training-Data-Development" data-toc-modified-id="Pre-Processing-and-Training-Data-Development-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Pre-Processing and Training Data Development</a></span></li><li><span><a href="#Machine-Learning-Modeling" data-toc-modified-id="Machine-Learning-Modeling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Machine Learning Modeling</a></span><ul class="toc-item"><li><span><a href="#Base-Support-Vector-Machine-Model-with-Default-Hyper-Parameters" data-toc-modified-id="Base-Support-Vector-Machine-Model-with-Default-Hyper-Parameters-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Base Support Vector Machine Model with Default Hyper Parameters</a></span></li><li><span><a href="#Finding-Best-Hyper-Parameters-using-GridSearchCV" data-toc-modified-id="Finding-Best-Hyper-Parameters-using-GridSearchCV-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Finding Best Hyper Parameters using GridSearchCV</a></span></li></ul></li><li><span><a href="#Documentation" data-toc-modified-id="Documentation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Documentation</a></span><ul class="toc-item"><li><span><a href="#Final-Model-Evaluation" data-toc-modified-id="Final-Model-Evaluation-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Final Model Evaluation</a></span></li><li><span><a href="#Project-References-&amp;-Resources" data-toc-modified-id="Project-References-&amp;-Resources-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Project References &amp; Resources</a></span></li><li><span><a href="#Project-Video-Walk-Through" data-toc-modified-id="Project-Video-Walk-Through-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Project Video Walk-Through</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Project Title: Using Support Vector Machine (SVM) Regression, Predict Concrete Compressive Strength based on Concrete Slump Tests

# %% [markdown]
# ![ConcreteSlump_900x600.jpg](attachment:ConcreteSlump_900x600.jpg)

# %% [markdown]
# ## Project Background

# %% [markdown]
# As per wikipedia (https://en.wikipedia.org/wiki/Concrete_slump_test), the concrete slump test measures the consistency of fresh concrete before it sets. It is performed to check the **workability of freshly made concrete**, and therefore the ease with which concrete flows. It can also be used as an indicator of an improperly mixed batch. The test is popular due to the simplicity of apparatus used and simple procedure. **The slump test is used to ensure uniformity for different loads of concrete under field conditions.**
#
# Accordingly, its slump rating indicates what construction application the concrete is good for. The higher the slump, the more workable the concrete.
#
# Concrete is composed of **four main ingredients: cement, water, fine aggregate (sand), and coarse aggregate (rock)**. Recycled cementitious materials such as slag and fly ash are also substituted for cement, to provide varying effects on the concrete’s plastic and hardened properties.
#
# The main purpose of this project is to **use the Support Vector Machine (SVM) Regression Modeling, a supervised learning algorithm** to simulate compressive strength of the concrete.

# %% [markdown]
# ## Project Methodology

# %% [markdown]
# ![MLmethodology.jpg](attachment:MLmethodology.jpg)

# %% [markdown]
# ## Problem Identification

# %% [markdown]
# ![MLinfograph1.jpg](attachment:MLinfograph1.jpg)

# %% [markdown]
# **Hypothesis:** Using Support Vector Machine (SVM) Regression, simulate Concrete Compressive Strength & Concrete Slump Machine Learning Model
#
# **Significance of Concrete Slump Test:** As per Concrete101 (https://www.centreconcrete.com/concrete101.html), **slump is the measure of concrete consistency and fluidity**. It shows the flow and overall workability of freshly mixed concrete. Simply put, the higher the slump, the wetter the mix. Four-inch (4”) slump is very common with normal weight concrete and is a good for pumping. Slumps that are above average will cause reduced strength, durability, and permeability of the concrete. Admixtures should be used instead of water to achieve higher slumps so that you can maintain the quality of your concrete.
#
# **Data Source:** In order to support machine learning algorithm, UCI Machine Learning Respository has made the data available for specific to this purpose which will be utilized for this project.

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ![MLinfograph2.jpg](attachment:MLinfograph2.jpg)

# %% [markdown]
# ## Identification and Collection of Datasets

# %% [markdown]
# A big thanks to UCI Machine Learning Repository team (https://archive.ics.uci.edu/ml/datasets/Concrete+Slump+Test), which has made this dataset available for this specific purpose of modeling and simulating concrete compressive strength and concrete slump analysis.
#
# ![uci_concrete_slump.png](attachment:uci_concrete_slump.png)
#
# For the purpose of this project, I have downloaded data from the above source and it is now available for machine learning modeling purpose.

# %% [markdown]
# ## Loading of Core Packages

# %%
# Load core packages for the project
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Importing and reading csv file of the dataset
df = pd.read_csv('cement_slump.csv')
df.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
#    FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0      62.0                               34.99
# 1      20.0                               41.14
# 2      20.0                               41.81
# 3      21.5                               42.08
# 4      64.0                               26.82

# %% [markdown]
# Here 'Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.', and 'Fine Aggr.' are input parameters for the slump test and output parameters of the slump test are 'SLUMP(cm)', 'FLOW(cm)', and 'Compressive Strength (28-day)(Mpa)'.
#
# For the purpose of this supervised machine learning modeling, 'Compressive Strength (28-day)(Mpa)' is the target variable and others are features.

# %%
# Checking for the shape
df.shape
# Out:
# (103, 10)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ![MLinfograph3.jpg](attachment:MLinfograph3.jpg)

# %%
# Checking for the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Cement                              103 non-null    float64
#  1   Slag                                103 non-null    float64
#  2   Fly ash                             103 non-null    float64
#  3   Water                               103 non-null    float64
#  4   SP                                  103 non-null    float64
#  5   Coarse Aggr.                        103 non-null    float64
#  6   Fine Aggr.                          103 non-null    float64
#  7   SLUMP(cm)                           103 non-null    float64
#  8   FLOW(cm)                            103 non-null    float64
#  9   Compressive Strength (28-day)(Mpa)  103 non-null    float64
# dtypes: float64(10)
# memory usage: 8.2 KB

# %%
# Checking if any data is missing
df.isna().any()
# Out:
# Cement                                False
# Slag                                  False
# Fly ash                               False
# Water                                 False
# SP                                    False
# Coarse Aggr.                          False
# Fine Aggr.                            False
# SLUMP(cm)                             False
# FLOW(cm)                              False
# Compressive Strength (28-day)(Mpa)    False
# dtype: bool

# %% [markdown]
# There is no missing information and all the features as well as the target are of float type.

# %%
# Checking for the distribution of Cement for the outliers and it's pattern
sns.displot(df['Cement'],kde=True)
plt.title("Distribution Plot for Cement")
plt.show()

# %%
# Checking for the distribution of Slag for the outliers and it's pattern
sns.displot(df['Slag'],kde=True)
plt.title("Distribution Plot for Slag")
plt.show()

# %%
# Checking for the distribution of Fly ash for the outliers and it's pattern
sns.displot(df['Fly ash'],kde=True)
plt.title("Distribution Plot for Fly ash")
plt.show()

# %%
# Checking for the distribution of Water for the outliers and it's pattern
sns.displot(df['Water'],kde=True)
plt.title("Distribution Plot for Water")
plt.show()

# %%
# Checking for the distribution of SP for the outliers and it's pattern
sns.displot(df['SP'],kde=True)
plt.title("Distribution Plot for SP")
plt.show()

# %%
# Checking for the distribution of Coarse Aggr. for the outliers and it's pattern
sns.displot(df['Coarse Aggr.'],kde=True)
plt.title("Distribution Plot for Coarse Aggr.")
plt.show()

# %%
# Checking for the distribution of Fine Aggr. for the outliers and it's pattern
sns.displot(df['Fine Aggr.'],kde=True)
plt.title("Distribution Plot for Fine Aggr.")
plt.show()

# %%
# Checking for the pairplot
sns.pairplot(df)
plt.show()

# %%
# Checking for the correlations
df.corr()
# Out:
#                                       Cement      Slag   Fly ash     Water  \
# Cement                              1.000000 -0.243553 -0.486535  0.221091
# Slag                               -0.243553  1.000000 -0.322619 -0.026775
# Fly ash                            -0.486535 -0.322619  1.000000 -0.241321
# Water                               0.221091 -0.026775 -0.241321  1.000000
# SP                                 -0.106387  0.306504 -0.143508 -0.155456
# Coarse Aggr.                       -0.309857 -0.223792  0.172620 -0.602201
# Fine Aggr.                          0.056959 -0.183522 -0.282854  0.114591
# SLUMP(cm)                           0.145913 -0.284037 -0.118621  0.466568
# FLOW(cm)                            0.186461 -0.327231 -0.055423  0.632026
# Compressive Strength (28-day)(Mpa)  0.445656 -0.331522  0.444380 -0.254320
#
#                                           SP  Coarse Aggr.  Fine Aggr.  \
# ...

# %%
# Plotting the heatmap for the correlated data
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='viridis')
plt.show()

# %% [markdown]
# Here is the correlations summary based on the above analysis:
#
# - Negative correlation between Fly ash and Cement
# - Negative correlation between Water and Coarse Aggregates
# - Negative correlation between Fine Aggregates and Coarse Aggregates
# - Positive correlation between Slump and Water
# - Positive correlation between Flow and Water
# - Pretty strong positive correlation between Flor and Slump
# - Positive correlation between Compressive Strength and Cement
# - Positive correlation between Compressive Strength and Fly ash

# %%
# Since the target variable is known, I can also get the correlations directly with the target variable
df.corr()['Compressive Strength (28-day)(Mpa)']
# Out:
# Cement                                0.445656
# Slag                                 -0.331522
# Fly ash                               0.444380
# Water                                -0.254320
# SP                                   -0.037909
# Coarse Aggr.                         -0.160610
# Fine Aggr.                           -0.154532
# SLUMP(cm)                            -0.223499
# FLOW(cm)                             -0.124189
# Compressive Strength (28-day)(Mpa)    1.000000
# Name: Compressive Strength (28-day)(Mpa), dtype: float64

# %% [markdown]
# # Pre-Processing and Training Data Development

# %% [markdown]
# ![MLinfograph4.jpg](attachment:MLinfograph4.jpg)

# %%
# Importing required packages
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Keeping column names handy for future if required
df.columns
# Out:
# Index(['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.',
#        'Fine Aggr.', 'SLUMP(cm)', 'FLOW(cm)',
#        'Compressive Strength (28-day)(Mpa)'],
#       dtype='object')

# %%
# Defining X and y
X = df.drop('Compressive Strength (28-day)(Mpa)', axis=1)
y = df['Compressive Strength (28-day)(Mpa)']

# %%
# Splitting into training (70%) and testing (30%) datasets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=101)

# %%
# Standardizing dataset with Standard Scaler and Scaling is a MUST for Support Vector Machine modeling
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# # Machine Learning Modeling

# %% [markdown]
# ![MLinfograph5.jpg](attachment:MLinfograph5.jpg)

# %%
# Importing required packages
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Base Support Vector Machine Model with Default Hyper Parameters

# %%
# default values for SVM
# help(SVR)

# Default Hyper Parameters for SVR:

# SVR(*, kernel='rbf', degree=3, gamma='scale', coef0=0.0, tol=0.001, C=1.0, epsilon=0.1, 
# shrinking=True, cache_size=200, verbose=False, max_iter=-1)

# %%
base_model = SVR()

# %%
# Fitting scaled X_train and y_train and then predict with base model
base_model.fit(scaled_X_train,y_train)
base_pred = base_model.predict(scaled_X_test)

# %%
# Finding mean absolute error for the base model
print("Mean Absolute Error is:",mean_absolute_error(y_test,base_pred))
# Out:
# Mean Absolute Error is: 5.236902091259179

# %%
# Finding mean squared error for the base model
print("Mean Squared Error is:",np.sqrt(mean_squared_error(y_test,base_pred)))
# Out:
# Mean Squared Error is: 6.695914838327133

# %%
# Finding the mean value for the y_test
print("Mean value of the y_test is:", y_test.mean())
# Out:
# Mean value of the y_test is: 36.26870967741935

# %% [markdown]
# ## Finding Best Hyper Parameters using GridSearchCV

# %%
# Importing required package
from sklearn.model_selection import GridSearchCV

# %%
# Defining parameters for the grid search
param_grid = {'kernel': ['linear', 'rbf', 'poly'],
             'degree':[2,3,4],
             'gamma': ['scale','auto'],
             'C': [0.001,0.01,0.1,0.5,1],
             'epsilon': [0,0.001,0.01,0.1,0.5,1,2]}

# %%
# Performing cross validation on the training dataset
svr = SVR()
grid = GridSearchCV(svr, param_grid)

# %%
# Fitting scaled training data set
grid.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1], 'degree': [2, 3, 4],
#                          'epsilon': [0, 0.001, 0.01, 0.1, 0.5, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
# Finding the best parameters
grid.best_params_
# Out:
# {'C': 1, 'degree': 2, 'epsilon': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %%
# Finding predicted values based on the above best paramters selected by the Grid Search
grid_pred = grid.predict(scaled_X_test)

# %%
# Finding mean absolute error for the grid model
print("Mean Absolute Error for Grid Model is:",mean_absolute_error(y_test,grid_pred))
# Out:
# Mean Absolute Error for Grid Model is: 2.512801221076198

# %%
# Finding mean squared error for the grid model
print("Mean Squared Error for Grid Model is:",np.sqrt(mean_squared_error(y_test,grid_pred)))
# Out:
# Mean Squared Error for Grid Model is: 3.1782103051198347

# %% [markdown]
# **Both mean absolute error as well as mean squared error are relatively much lower with the parameters selected by the Grid Search.**

# %% [markdown]
# # Documentation

# %% [markdown]
# ![MLinfograph6.jpg](attachment:MLinfograph6.jpg)

# %% [markdown]
# ## Final Model Evaluation

# %% [markdown]
# **1. Base Model for Support Vector Machine Regression Model**

# %%
# Finding mean absolute error for the base model
print("Mean Absolute Error for Base Model is:",mean_absolute_error(y_test,base_pred))
# Out:
# Mean Absolute Error for Base Model is: 5.236902091259179

# %%
# Finding mean squared error for the base model
print("Mean Squared Error for Base Model is:",np.sqrt(mean_squared_error(y_test,base_pred)))
# Out:
# Mean Squared Error for Base Model is: 6.695914838327133

# %% [markdown]
# **2. Optimized Model for SVM Regression based on GridSearchCV Best Parameters**

# %%
# Finding mean absolute error for the grid model
print("Mean Absolute Error for Grid Optimized Model is:",mean_absolute_error(y_test,grid_pred))
# Out:
# Mean Absolute Error for Grid Optimized Model is: 2.512801221076198

# %%
# Finding mean squared error for the grid model
print("Mean Squared Error for Grid Optimized Model is:",np.sqrt(mean_squared_error(y_test,grid_pred)))
# Out:
# Mean Squared Error for Grid Optimized Model is: 3.1782103051198347

# %% [markdown]
# **Based on the above, optimized model is a clear winner.**

# %% [markdown]
# ## Project References & Resources

# %% [markdown]
# - https://scikit-learn.org/stable/modules/svm.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
# - https://scikit-learn.org/stable/auto_examples/svm/plot_svm_regression.html

# %% [markdown]
# ## Project Video Walk-Through

# %% [markdown]
# Watch the Project video walk-through on YouTube by clicking here at https://www.youtube.com/watch?v=YECJUHqWgDo

# %% [markdown]
# ![svr_vw_cover.png](attachment:svr_vw_cover.png)

# %% [markdown]
# The above video image is provided here for your easy reference so that you watch the right video on YouTube.
